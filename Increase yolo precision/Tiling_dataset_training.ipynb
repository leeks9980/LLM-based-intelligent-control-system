# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO
import cv2

# %%
model = YOLO(r"C:\Users\lijih\code\mine\Project(25_2)\yoloV8_Human Motion Detection_Aerial Photography\yolov8n.pt")

model.train(
    data=r"C:\Users\lijih\code\drone_dataset_size\data.yaml",   
    epochs=50,                  
    imgsz=640,                  
    batch=8,                    
    device=0,
    workers=0              
    )
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.11.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# 모델 불러오기
model = YOLO(r"C:\Users\lijih\code\mine\Project(25_2)\yoloV8_Human Motion Detection_Aerial Photography\runs\detect\train\weights\best.pt")

# 추론
results = model.predict(
    r"C:\Users\lijih\OneDrive\바탕 화면\4\4\DJI_20250918174728_0114_V.JPG",
    conf=0.5 
)
results[0].show()
# Out:
# image 1/1 C:\Users\lijih\OneDrive\ \4\4\DJI_20250918174728_0114_V.JPG: 480x640 6 cars, 20.0ms
# Speed: 3.2ms preprocess, 20.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
